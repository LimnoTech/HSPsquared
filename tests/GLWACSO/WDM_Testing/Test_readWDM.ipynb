# %% [markdown]
# # HSP2 BUILD and RUN SIMULATION
#
# This Jupyter Notebook is for testing HSP2tools.readWDM() with the WDM files for GLWACSO that have not been reading in properly. The problematic WDM file has been separated into 9 files (one for each constituent) with 48 time series for each location.

# %% [markdown]
# ## Required Python Imports

# %%
import HSP2
import HSP2tools

from glob import glob

# %%
#Commented out due to errors with .versions()

#HSP2tools.versions()

# %% [markdown]
# ## BUILD HDF5 FILE From WDM files

# %% [markdown]
# Add the timeseries data to the HDF5 file.

# %%
wdmnames = glob('*.wdm')

wdmnames
# Out:
# ['1_RPO_SWMM48LINKS2017_FLOW.wdm',
#  '2_RPO_SWMM48LINKS2017_CBOD.wdm',
#  '3_RPO_SWMM48LINKS2017_DO.wdm',
#  '4_RPO_SWMM48LINKS2017_FCOL.wdm',
#  '5_RPO_SWMM48LINKS2017_NH3N.wdm',
#  '6_RPO_SWMM48LINKS2017_NOXN.wdm',
#  '7_RPO_SWMM48LINKS2017_PO4P.wdm',
#  '8_RPO_SWMM48LINKS2017_TORN.wdm',
#  '9_RPO_SWMM48LINKS2017_TORP.wdm']

# %%
# Commented Out due to long run times with no resolution. Used cells above to test reading in the WDM files separately.
#file_no = 1

#for name in wdmnames:
#    HDFname = 'HDF_test_' + str(file_no) + '.h5'
#    HSP2tools.readWDM(name, HDFname)
#    file_no = file_no + 1

# %% [markdown]
# Add each WDM file one at a time and create a new .h5 file after each to see the file configuration when it stops.

# %%
HSP2tools.readWDM('1_RPO_SWMM48LINKS2017_CBOD.wdm', 'HDF_test_1.h5')

# %%
HSP2tools.readWDM('2_RPO_SWMM48LINKS2017_CBOD.wdm', 'HDF_test_2.h5')

# %%
HSP2tools.readWDM('3_RPO_SWMM48LINKS2017_DO.wdm', 'HDF_test_3.h5')

# %%
HSP2tools.readWDM('4_RPO_SWMM48LINKS2017_FCOL.wdm', 'HDF_test_4.h5')

# %%
HSP2tools.readWDM('5_RPO_SWMM48LINKS2017_NH3N.wdm', 'HDF_test_5.h5')
# Out:
#                      Start                 Stop   Freq  Length TSTYPE  TFILL  \
# TS334  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NH3N -999.0
# TS338  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NH3N -999.0
# TS340  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NH3N -999.0
# TS339  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NH3N -999.0
# TS343  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NH3N -999.0
# TS347  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NH3N -999.0
# TS319  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NH3N -999.0
# TS321  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NH3N -999.0
# TS331  2004-01-01 00:00:00  2018-01-01 00:00:00  15min  490944   NH3N -999.0
# TS350  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NH3N -999.0
# TS353  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NH3N -999.0
# ...

# %%
HSP2tools.readWDM('6_RPO_SWMM48LINKS2017_NOXN.wdm', 'HDF_test_6.h5')
# Out:
#                      Start                 Stop   Freq  Length TSTYPE  TFILL  \
# TS434  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NOXN -999.0
# TS438  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NOXN -999.0
# TS440  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NOXN -999.0
# TS439  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NOXN -999.0
# TS443  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NOXN -999.0
# TS447  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NOXN -999.0
# TS419  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NOXN -999.0
# TS421  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NOXN -999.0
# TS450  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NOXN -999.0
# TS453  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NOXN -999.0
# TS459  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   NOXN -999.0
# ...

# %%
HSP2tools.readWDM('7_RPO_SWMM48LINKS2017_PO4P.wdm', 'HDF_test_7.h5')
# Out:
#                      Start                 Stop   Freq  Length TSTYPE  TFILL  \
# TS734  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   PO4P -999.0
# TS738  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   PO4P -999.0
# TS740  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   PO4P -999.0
# TS739  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   PO4P -999.0
# TS743  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   PO4P -999.0
# TS747  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   PO4P -999.0
# TS719  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   PO4P -999.0
# TS731  2004-01-01 00:00:00  2018-01-01 00:00:00  15min  490944   PO4P -999.0
# TS721  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   PO4P -999.0
# TS750  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   PO4P -999.0
# TS753  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   PO4P -999.0
# ...

# %%
HSP2tools.readWDM('8_RPO_SWMM48LINKS2017_TORN.wdm', 'HDF_test_8.h5')
# Out:
#                      Start                 Stop   Freq  Length TSTYPE  TFILL  \
# TS534  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   TORN -999.0
# TS538  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   TORN -999.0
# TS540  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   TORN -999.0
# TS539  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   TORN -999.0
# TS543  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   TORN -999.0
# TS547  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   TORN -999.0
# TS519  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   TORN -999.0
# TS521  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   TORN -999.0
# TS531  2004-01-01 00:00:00  2018-01-01 00:00:00  15min  490944   TORN -999.0
# TS550  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   TORN -999.0
# TS553  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   TORN -999.0
# ...

# %%
HSP2tools.readWDM('9_RPO_SWMM48LINKS2017_TORP.wdm', 'HDF_test_9.h5')
# Out:
#                      Start                 Stop   Freq  Length TSTYPE  TFILL  \
# TS634  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   TORP -999.0
# TS638  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   TORP -999.0
# TS640  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   TORP -999.0
# TS639  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   TORP -999.0
# TS643  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   TORP -999.0
# TS647  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   TORP -999.0
# TS619  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   TORP -999.0
# TS631  2004-01-01 00:00:00  2018-01-01 00:00:00  15min  490944   TORP -999.0
# TS621  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   TORP -999.0
# TS650  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   TORP -999.0
# TS653  2004-01-01 00:00:00  2007-01-01 00:00:00  15min  105216   TORP -999.0
# ...

# %% [markdown]
# # Lessons Learned (So far...)

# %% [markdown]
#  11/25/2020 BJC
#
#  The following files all appear to work correctly:
#   '5_RPO_SWMM48LINKS2017_NH3N.wdm',
#  '6_RPO_SWMM48LINKS2017_NOXN.wdm',
#  '7_RPO_SWMM48LINKS2017_PO4P.wdm',
#  '8_RPO_SWMM48LINKS2017_TORN.wdm',
#  '9_RPO_SWMM48LINKS2017_TORP.wdm'
#
#  There are problems reading in all of the other 4 files. None of these files completed running (needed to stop the kernel).
#  '1_RPO_SWMM48LINKS2017_FLOW.wdm': File created only has 10 timeseries listed
#  '2_RPO_SWMM48LINKS2017_CBOD.wdm': File created only has 17 timeseries listed
#  '3_RPO_SWMM48LINKS2017_DO.wdm': Error opening the file created (only 1 KB - maybe none of them read in)
#  '4_RPO_SWMM48LINKS2017_FCOL.wdm': File created only has 12 timeseries listed

# %% [markdown]
# # Cells below here are old legacy cells to use for copying and pasting.

# %%
HSP2tools.readWDM('model_files\KDTWMet-06272019-KOS_w_Mon17Filled_CHLA_ComDO.wdm', HDFname)

# %%
# !copy GLWA_HSPF_June2019_Mon8MileDataFilled_WT_RW_v4.h5 GLWA_HSPF_June2019_Mon8MileDataFilled_WT_RW_v4_WDM1.h5

# %%
HSP2tools.readWDM('model_files\RPO_SWMM24NODES2017_wCBOD_June2019.wdm', HDFname)

# %%
# !copy GLWA_HSPF_June2019_Mon8MileDataFilled_WT_RW_v4.h5 GLWA_HSPF_June2019_Mon8MileDataFilled_WT_RW_v4_WDM2.h5

# %%
HSP2tools.readWDM('model_files\WDM_2017_UpdatedBOD.wdm', HDFname)

# %%
# !copy GLWA_HSPF_June2019_Mon8MileDataFilled_WT_RW_v4.h5 GLWA_HSPF_June2019_Mon8MileDataFilled_WT_RW_v4_WDM3.h5

# %%
#Testing this with an alternative HDFname

HSP2tools.readWDM('model_files\RPO_SWMM48LINKS2017_wCBOD_June2019.wdm', HDFname)
#HSP2tools.readWDM('RPO_SWMM48LINKS2017_wCBOD_June2019.wdm', 'HDF_test.h5')

# %%
# !rename {HDFname} temp.h5
# !ptrepack temp.h5 {HDFname}
# !del temp.h5
